# %% [markdown]
# Dataset link :- [Neonatal Dataset from Kaggle](https://www.kaggle.com/datasets/programmerrdai/child-and-infant-mortality?select=neonatal-deaths-by-cause.csv)
# <br>
# PPT LINK:- [Milestone 2](https://docs.google.com/presentation/d/1NU6qruqAdhOgB6Xg53q1LmW3fba8a4ZVBpaffNjoYj0/edit?usp=sharing)

# %%
import pandas as pd

# %% [markdown]
# Read the data

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23a63d0f-209b-4637-9fd1-98f9807dd27f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23a63d0f-209b-4637-9fd1-98f9807dd27f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df = pd.read_csv(io.BytesIO(uploaded['neonatal-deaths-by-cause.csv']))
#df=pd.read_csv("C:\\Users\\Namita\\OneDrive\\Desktop\\neonatal-deaths-by-cause.csv")

# %% [markdown]
# Dropping NaN values <br>
# (Just for the sake of it, this data does not have any NaN values. It's a pretty decent dataset.)

# %%
df=df.dropna()

# %% [markdown]
# Describe the dataset

# %%
df.describe()
# Out:
#               Year  \
# count  6150.000000
# mean   2004.500000
# std       8.656145
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)  \
# count                                        6150.000000
# mean                                         1133.177561
# std                                          9223.101449
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             5.000000
# 75%                                           163.750000
# max                                        199358.000000
#
#        Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)  \
# count                                        6150.000000
# mean                                         2968.574472
# ...

# %% [markdown]
# Column Names

# %%
print("Column names for dataset: \n\n",df.columns)
# Out:
# Column names for dataset:
#
#  Index(['Entity', 'Code', 'Year',
#        'Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Hemolytic disease and other neonatal jaundice - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Lower respiratory infections - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Meningitis - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Neonatal preterm birth - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Tetanus - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Other unspecified infectious diseases - Sex: Both - Age: 0-27 days (Number)',
# ...

# %%
df.head(3)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
#
#    Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                486
# 1                                                598
# 2                                                765
#
#    Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)  \
# 0                                               4872
# 1                                               5493
# 2                                               6542
#
#    Deaths - Hemolytic disease and other neonatal jaundice - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                348
# 1                                                390
# 2                                                467
#
#    Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                  2
# ...

# %% [markdown]
# <h1><b>Exploring the statistical description of the dataset</b></h1>

# %% [markdown]
# Data shape

# %%
print("The shape of this data:",df.shape)
# Out:
# The shape of this data: (6150, 16)

# %% [markdown]
# Median

# %%
print("Median: \n",df.median(axis =0))
# Out:
# Median:
#  Year                                                                                                       2004.5
# Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)                                             5.0
# Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)                                     202.0
# Deaths - Hemolytic disease and other neonatal jaundice - Sex: Both - Age: 0-27 days (Number)                  6.0
# Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)                                                        0.0
# Deaths - Lower respiratory infections - Sex: Both - Age: 0-27 days (Number)                                  43.0
# Deaths - Meningitis - Sex: Both - Age: 0-27 days (Number)                                                     4.0
# Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: 0-27 days (Number)     186.0
# ...

# %% [markdown]
# Mode

# %%
print("Mode:",df.mode())
df.mode()
# Out:
# Mode:              Entity Code    Year  \
# 0       Afghanistan  AFG  1990.0
# 1           Albania  AGO  1991.0
# 2           Algeria  ALB  1992.0
# 3    American Samoa  AND  1993.0
# 4           Andorra  ARE  1994.0
# ..              ...  ...     ...
# 200         Vietnam  WSM     NaN
# 201           World  YEM     NaN
# 202           Yemen  ZAF     NaN
# 203          Zambia  ZMB     NaN
# 204        Zimbabwe  ZWE     NaN
#
#      Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                  0.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 200                                                NaN
# 201                                                NaN
# ...

# %% [markdown]
# <h1><u>segregation of data</u></h1>
#  - When selecting subsets of data, square brackets [] are used.
#  - Inside these brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#  - Select specific rows and/or columns using loc when using the row and column names.
#  - Select specific rows and/or columns using iloc when using the positions in the table.

# %%
#external causes for death
ext= df[['Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)'
        ,'Deaths - Meningitis - Sex: Both - Age: 0-27 days (Number)'
       ,'Deaths - Hemolytic disease and other neonatal jaundice - Sex: Both - Age: 0-27 days (Number)'
        ,'Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)']]
ext
# Out:
#       Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                   486
# 1                                                   598
# 2                                                   765
# 3                                                   973
# 4                                                   971
# ...                                                 ...
# 6835                                                 88
# 6836                                                 81
# 6837                                                 79
# 6838                                                 73
# 6839                                                 68
#
#       Deaths - Meningitis - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                   199
# 1                                                   218
# 2                                                   257
# ...

# %%
#transmitted diseases
trans =df[['Deaths - Sexually transmitted infections excluding HIV - Sex: Both - Age: 0-27 days (Number)'
          ,'Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)'
          ,'Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: 0-27 days (Number)'
          ,'Deaths - Tetanus - Sex: Both - Age: 0-27 days (Number)']]
trans
# Out:
#       Deaths - Sexually transmitted infections excluding HIV - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                    99
# 1                                                   107
# 2                                                   146
# 3                                                   192
# 4                                                   210
# ...                                                 ...
# 6835                                                305
# 6836                                                301
# 6837                                                298
# 6838                                                301
# 6839                                                311
#
#       Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                  4872
# 1                                                  5493
# ...

# %%
#unspecified reasons for death
unspec =df[['Deaths - Other unspecified infectious diseases - Sex: Both - Age: 0-27 days (Number)'
           ,'Deaths - Other neonatal disorders - Sex: Both - Age: 0-27 days (Number)'
           ,'Deaths - Neonatal sepsis and other neonatal infections - Sex: Both - Age: 0-27 days (Number)'
           ,'Deaths - Neonatal preterm birth - Sex: Both - Age: 0-27 days (Number)']]
unspec
# Out:
#       Deaths - Other unspecified infectious diseases - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                    63
# 1                                                    76
# 2                                                    94
# 3                                                   104
# 4                                                   107
# ...                                                 ...
# 6835                                                 13
# 6836                                                 11
# 6837                                                 11
# 6838                                                 13
# 6839                                                 11
#
#       Deaths - Other neonatal disorders - Sex: Both - Age: 0-27 days (Number)  \
# 0                                                  5811
# 1                                                  6281
# 2                                                  7193
# ...

# %% [markdown]
# <h1><b>Visualization</b></h1>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b>Visualizations for every dataframe partition</b>

# %% [markdown]
# <h2>External death factors</h2>

# %%
ext=ext[:500]

# %%
#Line graph
ext.plot()

# %%
# Line Graph for all columns
ext.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
ext.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
ext.diff().hist();

# %%
#Area plot
ext.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Transmitted diseases</h2>

# %%
#Line graph
trans.plot()
# Out:
# <AxesSubplot:>

# %%
#line graph for each column
trans.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
trans.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
trans.diff().hist();

# %%
#Area plot
trans.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Unspecified diseases</h2>

# %%
#line graph for unspecified diseases
unspec.plot()
# Out:
# <AxesSubplot:>

# %%
#line graph for all columns
unspec.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
unspec.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
unspec.diff().hist();

# %%
#Area plot
unspec.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Additional visualizations for more insights</h2>

# %%
#A pandas Series is 1-dimensional and only the number of rows is returned.
malaria=df['Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)']
tetnus=df['Deaths - Tetanus - Sex: Both - Age: 0-27 days (Number)']
year=df['Year']

# %%
print('tetnus shape:',tetnus.shape)
print('malaria shape:',malaria.shape)
# Out:
# tetnus shape: (6150,)
# malaria shape: (6150,)

# %%
malaria=malaria[:100]
tetnus=tetnus[:100]

# %%
themes=plt.style.available
print(themes)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
X = df.drop([ 'Deaths - Other unspecified infectious diseases - Sex: Both - Age: 0-27 days (Number)'], axis=1)
y = df['Year']

# %%
plt.scatter(malaria,year)
plt.title('Deaths due to Malaria over the years')
plt.xlabel('Malaria')
plt.ylabel("years")
plt.legend(loc='upper right', labels=['Malaria'])
plt.style.use('seaborn')
plt.show()

# %%
x=malaria[:100]
y=year

# %%
sns.jointplot(x,y, data=df, size=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x,y, data=df)
# Out:
# C:\Users\Namita\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)', ylabel='Year'>

# %%
sns.violinplot(x,y, data=df)
# Out:
# C:\Users\Namita\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)', ylabel='Year'>

# %%
sns.pairplot( data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <h2>Comparisons of deaths from earlier times to current times</h2>

# %%
print(ext.columns)
print(trans.columns)
print(unspec.columns)
# Out:
# Index(['Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Meningitis - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Hemolytic disease and other neonatal jaundice - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Malaria - Sex: Both - Age: 0-27 days (Number)'],
#       dtype='object')
# Index(['Deaths - Sexually transmitted infections excluding HIV - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Congenital birth defects - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Tetanus - Sex: Both - Age: 0-27 days (Number)'],
#       dtype='object')
# Index(['Deaths - Other unspecified infectious diseases - Sex: Both - Age: 0-27 days (Number)',
#        'Deaths - Other neonatal disorders - Sex: Both - Age: 0-27 days (Number)',
# ...

# %% [markdown]
# <b>Diarhea in early times with joinplot(External diseases example)</b>

# %%
dirhea=df['Deaths - Diarrheal diseases - Sex: Both - Age: 0-27 days (Number)']
dirhea[:5]
y1=y[:5]

# %%
sns.jointplot(dirhea,y1, data=df, size=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %% [markdown]
# Diarhea now

# %%
y2=y[:-5]
y2
# Out:
# 0       1990
# 1       1991
# 2       1992
# 3       1993
# 4       1994
#         ...
# 6830    2010
# 6831    2011
# 6832    2012
# 6833    2013
# 6834    2014
# Name: Year, Length: 6145, dtype: int64

# %%
sns.jointplot(dirhea,y, data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <b>Deaths due to HIV before and now (transmitted diseases sample)</b>

# %%
hiv=df['Deaths - Sexually transmitted infections excluding HIV - Sex: Both - Age: 0-27 days (Number)']

# %%
hiv1=hiv[:5]

# %%
hiv2=hiv[:-5]

# %%
plt.scatter(hiv1,y1, label='old')
# plt.scatter(hiv2,y2,color='blue')
plt.title('HIV old times')
plt.xlabel('Deaths')
plt.ylabel('Year')
plt.legend()
plt.show()

# %%
plt.scatter(hiv2,y2,label='new',color='blue')
plt.title('HIV  now')
plt.xlabel('Deaths')
plt.ylabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# <b>Deaths due to Neonatal infection(Unspecified disease example)</b>

# %%
neo=df['Deaths - Neonatal sepsis and other neonatal infections - Sex: Both - Age: 0-27 days (Number)']

# %%
sns.jointplot(neo,y1, data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
sns.jointplot(neo,y2, data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %% [markdown]
# <h2>**second dataset**</h2><br>
# by Naindeep

# %% [markdown]
# Second Data link :- [Causes of Death](https://www.kaggle.com/datasets/programmerrdai/child-and-infant-mortality?select=causes-of-death-in-children.csv)

# %%
import pandas as pd
import io

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2bfb556c-4a2c-434c-bdd3-ddc5955d7ee1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bfb556c-4a2c-434c-bdd3-ddc5955d7ee1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['causes-of-death-in-children.csv']))
#df = pd.read_csv(io.BytesIO(uploaded['neonatal-deaths-by-cause.csv']))

# %%
df=df.dropna()

# %%
df.describe()
# Out:
#               Year  Deaths - Malaria - Sex: Both - Age: Under 5 (Number)  \
# count  6150.000000                                        6150.000000
# mean   2004.500000                                        5284.376423
# std       8.656145                                       39887.382347
# min    1990.000000                                           0.000000
# 25%    1997.000000                                           0.000000
# 50%    2004.500000                                           0.000000
# 75%    2012.000000                                          74.750000
# max    2019.000000                                      631523.000000
#
#        Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)  \
# count                                        6150.000000
# mean                                         1409.682927
# std                                         11151.810727
# min                                             0.000000
# ...

# %%
df.head(3)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
#
#    Deaths - Malaria - Sex: Both - Age: Under 5 (Number)  \
# 0                                                 21
# 1                                                 41
# 2                                                 51
#
#    Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)  \
# 0                                                 10
# 1                                                 12
# 2                                                 13
#
#    Deaths - Meningitis - Sex: Both - Age: Under 5 (Number)  \
# 0                                               1709
# 1                                               1743
# 2                                               1954
#
#    Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)  \
# 0                                               1779
# 1                                               1822
# ...

# %%
print("The shape of this data:",df.shape)
# Out:
# The shape of this data: (6150, 20)

# %%
print("Median: \n",df.median(axis =0))
# Out:
# Median:
#  Year                                                                                                     2004.5
# Deaths - Malaria - Sex: Both - Age: Under 5 (Number)                                                        0.0
# Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)                                                       5.0
# Deaths - Meningitis - Sex: Both - Age: Under 5 (Number)                                                    33.0
# Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)                                      10.0
# Deaths - Other neonatal disorders - Sex: Both - Age: Under 5 (Number)                                     148.0
# Deaths - Whooping cough - Sex: Both - Age: Under 5 (Number)                                                12.0
# Deaths - Lower respiratory infections - Sex: Both - Age: Under 5 (Number)                                 227.0
# ...

# %%
print("Mode:",df.mode())
df.mode()
# Out:
# Mode:              Entity Code    Year  \
# 0       Afghanistan  AFG  1990.0
# 1           Albania  AGO  1991.0
# 2           Algeria  ALB  1992.0
# 3    American Samoa  AND  1993.0
# 4           Andorra  ARE  1994.0
# ..              ...  ...     ...
# 200         Vietnam  WSM     NaN
# 201           World  YEM     NaN
# 202           Yemen  ZAF     NaN
# 203          Zambia  ZMB     NaN
# 204        Zimbabwe  ZWE     NaN
#
#      Deaths - Malaria - Sex: Both - Age: Under 5 (Number)  \
# 0                                                  0.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 200                                                NaN
# 201                                                NaN
# ...

# %%
#transmitted diseases
trans =df[['Deaths - Whooping cough - Sex: Both - Age: Under 5 (Number)'
           ,'Deaths - Lower respiratory infections - Sex: Both - Age: Under 5 (Number)'
           ,'Deaths - Congenital birth defects - Sex: Both - Age: Under 5 (Number)'
           ,'Deaths - Measles - Sex: Both - Age: Under 5 (Number)'
          ,'Deaths - Syphilis - Sex: Both - Age: Under 5 (Number)']]
trans
# Out:
#       Deaths - Whooping cough - Sex: Both - Age: Under 5 (Number)  \
# 0                                                  2455
# 1                                                  2385
# 2                                                  2370
# 3                                                  2659
# 4                                                  3187
# ...                                                 ...
# 6835                                                518
# 6836                                                559
# 6837                                                544
# 6838                                                568
# 6839                                                536
#
#       Deaths - Lower respiratory infections - Sex: Both - Age: Under 5 (Number)  \
# 0                                                 20224
# 1                                                 20879
# 2                                                 23585
# ...

# %%
#external causes for death

ext = df [['Deaths - Malaria - Sex: Both - Age: Under 5 (Number)'
        ,'Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)'
        ,'Deaths - Tuberculosis - Sex: Both - Age: Under 5 (Number)'
          ,'Deaths - Diarrheal diseases - Sex: Both - Age: Under 5 (Number)']]
ext
# Out:
#       Deaths - Malaria - Sex: Both - Age: Under 5 (Number)  \
# 0                                                    21
# 1                                                    41
# 2                                                    51
# 3                                                    24
# 4                                                    52
# ...                                                 ...
# 6835                                               1475
# 6836                                               1219
# 6837                                               1249
# 6838                                               1213
# 6839                                               1207
#
#       Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)  \
# 0                                                    10
# 1                                                    12
# 2                                                    13
# ...

# %%
#unspecified reasons for death
unspec = df[['Deaths - Neonatal sepsis and other neonatal infections - Sex: Both - Age: Under 5 (Number)'
            ,'Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: Under 5 (Number)'
            ,'Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)'
            ,'Deaths - Other neonatal disorders - Sex: Both - Age: Under 5 (Number)']]
unspec
# Out:
#       Deaths - Neonatal sepsis and other neonatal infections - Sex: Both - Age: Under 5 (Number)  \
# 0                                                   420
# 1                                                   520
# 2                                                   662
# 3                                                   723
# 4                                                   736
# ...                                                 ...
# 6835                                               1265
# 6836                                               1235
# 6837                                               1204
# 6838                                               1178
# 6839                                               1170
#
#       Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: Under 5 (Number)  \
# 0                                                  1599
# 1                                                  1804
# ...

# %%
patte = df [['Deaths - Drowning - Sex: Both - Age: Under 5 (Number)'
            ,'Deaths - Neonatal preterm birth - Sex: Both - Age: Under 5 (Number)'
             ,'Deaths - Meningitis - Sex: Both - Age: Under 5 (Number)'
            ,'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Number)']]
patte
# Out:
#       Deaths - Drowning - Sex: Both - Age: Under 5 (Number)  \
# 0                                                   776
# 1                                                   748
# 2                                                   777
# 3                                                   872
# 4                                                   961
# ...                                                 ...
# 6835                                                126
# 6836                                                133
# 6837                                                133
# 6838                                                129
# 6839                                                127
#
#       Deaths - Neonatal preterm birth - Sex: Both - Age: Under 5 (Number)  \
# 0                                                  6088
# 1                                                  6791
# 2                                                  8098
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Line graph
trans.plot()

# %%
#line graph for each column
trans.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
trans.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
trans.diff().hist();

# %%
#Area plot
trans.plot.area()

# %%
ext=ext[:500]

# %%
#Line graph
ext.plot()

# %%
# Line Graph for all columns
ext.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
ext.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
ext.diff().hist();

# %%
#Area plot
ext.plot.area()

# %%
#Line graph
unspec.plot()

# %%
# Line Graph for all columns
unspec.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
unspec.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
unspec.diff().hist();

# %%
#Area plot
ext.plot.area()

# %%
#Line graph
patte.plot()

# %%
# Line Graph for all columns
patte.plot(subplots=True, figsize=(8, 8));

# %%
#histogram
patte.plot.hist(stacked=True, bins=20);

# %%
#hist for each column
patte.diff().hist();

# %%
#Area plot
patte.plot.area()
